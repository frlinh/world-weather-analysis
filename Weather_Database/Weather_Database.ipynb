# %%
# Import the dependencies.
import pandas as pd
import numpy as np

from citipy import citipy
from pprint import pprint

# %%
import time
from datetime import datetime
# Import the API key.
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | ponta delgada
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | malangali
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | garden city
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | zeya
# Processing Record 16 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 1 | izhevskoye
# Processing Record 18 of Set 1 | aras
# Processing Record 19 of Set 1 | constitucion
# Processing Record 20 of Set 1 | astana
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | belomorsk
# Processing Record 23 of Set 1 | tazovskiy
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | pahrump
# Processing Record 28 of Set 1 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | maryville
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | iqaluit
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | rutul
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | sawtell
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | naze
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | silver city
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | ciudad bolivar
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | matamoros
# Processing Record 12 of Set 2 | karasjok
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | gela
# Processing Record 16 of Set 2 | parsons
# Processing Record 17 of Set 2 | saint-francois
# Processing Record 18 of Set 2 | sioux lookout
# Processing Record 19 of Set 2 | kirakira
# Processing Record 20 of Set 2 | luau
# Processing Record 21 of Set 2 | middelburg
# Processing Record 22 of Set 2 | arosa
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | novyy urgal
# Processing Record 25 of Set 2 | bulawayo
# Processing Record 26 of Set 2 | barcelona
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | benjamin hill
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 2 | lae
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | santa isabel do rio negro
# Processing Record 36 of Set 2 | tahe
# Processing Record 37 of Set 2 | playas
# Processing Record 38 of Set 2 | lucapa
# Processing Record 39 of Set 2 | vardo
# Processing Record 40 of Set 2 | takoradi
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | mudyuga
# City not found. Skipping...
# Processing Record 44 of Set 2 | salaverry
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | namie
# Processing Record 48 of Set 2 | lianzhou
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | margate
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | paoua
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | nuuk
# Processing Record 9 of Set 3 | honningsvag
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 3 | aksha
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | esil
# Processing Record 16 of Set 3 | barabai
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 3 | balikpapan
# Processing Record 20 of Set 3 | russell
# Processing Record 21 of Set 3 | thinadhoo
# Processing Record 22 of Set 3 | severodvinsk
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | busselton
# Processing Record 30 of Set 3 | udachnyy
# Processing Record 31 of Set 3 | parrita
# Processing Record 32 of Set 3 | chardara
# Processing Record 33 of Set 3 | saint-pierre
# Processing Record 34 of Set 3 | port hardy
# Processing Record 35 of Set 3 | matadi
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | nurota
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | berbera
# Processing Record 42 of Set 3 | bathsheba
# Processing Record 43 of Set 3 | raozan
# City not found. Skipping...
# Processing Record 44 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 3 | biak
# Processing Record 46 of Set 3 | najran
# Processing Record 47 of Set 3 | sibu
# Processing Record 48 of Set 3 | havre-saint-pierre
# Processing Record 49 of Set 3 | achalpur
# Processing Record 50 of Set 3 | nome
# Processing Record 1 of Set 4 | ipixuna
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | kjollefjord
# Processing Record 4 of Set 4 | nhulunbuy
# Processing Record 5 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | itoman
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | rincon
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | obosi
# Processing Record 14 of Set 4 | caravelas
# Processing Record 15 of Set 4 | abu samrah
# Processing Record 16 of Set 4 | teberda
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | puerto guzman
# Processing Record 19 of Set 4 | raudeberg
# Processing Record 20 of Set 4 | mayor pablo lagerenza
# Processing Record 21 of Set 4 | piacabucu
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | mehamn
# Processing Record 24 of Set 4 | westport
# Processing Record 25 of Set 4 | tanshui
# City not found. Skipping...
# Processing Record 26 of Set 4 | coihaique
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | pinheiro machado
# Processing Record 31 of Set 4 | batticaloa
# Processing Record 32 of Set 4 | tlacolula
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | buchanan
# Processing Record 35 of Set 4 | broome
# Processing Record 36 of Set 4 | samarai
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | necochea
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | chimbote
# Processing Record 42 of Set 4 | millerovo
# Processing Record 43 of Set 4 | torbay
# Processing Record 44 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 4 | chapais
# Processing Record 46 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | matay
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | baden
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | newport
# Processing Record 5 of Set 5 | mikhaylovsk
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | bayanday
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | rio grande
# Processing Record 10 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | dingle
# Processing Record 12 of Set 5 | verkhnyaya toyma
# Processing Record 13 of Set 5 | waipawa
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 16 of Set 5 | spassk-ryazanskiy
# Processing Record 17 of Set 5 | otuzco
# Processing Record 18 of Set 5 | vila franca do campo
# Processing Record 19 of Set 5 | svetlyy
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | geraldton
# Processing Record 22 of Set 5 | hilo
# Processing Record 23 of Set 5 | saint-georges
# Processing Record 24 of Set 5 | krasnoselkup
# Processing Record 25 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 5 | mnogovershinnyy
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | gashua
# Processing Record 30 of Set 5 | harbin
# Processing Record 31 of Set 5 | madanapalle
# Processing Record 32 of Set 5 | teguldet
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 5 | suzuka
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 5 | belmonte
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | agirish
# Processing Record 41 of Set 5 | trinidad
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | tautira
# Processing Record 47 of Set 5 | innisfail
# Processing Record 48 of Set 5 | andapa
# Processing Record 49 of Set 5 | krasnoarmeysk
# Processing Record 50 of Set 5 | san rafael
# Processing Record 1 of Set 6 | ossora
# Processing Record 2 of Set 6 | ipubi
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | prince rupert
# Processing Record 5 of Set 6 | guilin
# Processing Record 6 of Set 6 | timra
# Processing Record 7 of Set 6 | sinnamary
# Processing Record 8 of Set 6 | tabas
# Processing Record 9 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | quarai
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 15 of Set 6 | maceio
# Processing Record 16 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 6 | ambilobe
# Processing Record 19 of Set 6 | muyezerskiy
# Processing Record 20 of Set 6 | adelaide
# Processing Record 21 of Set 6 | rosario do sul
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | myitkyina
# Processing Record 24 of Set 6 | leogane
# Processing Record 25 of Set 6 | carovigno
# Processing Record 26 of Set 6 | lubango
# Processing Record 27 of Set 6 | port elizabeth
# Processing Record 28 of Set 6 | sisimiut
# Processing Record 29 of Set 6 | tokur
# Processing Record 30 of Set 6 | save
# Processing Record 31 of Set 6 | thompson
# Processing Record 32 of Set 6 | haines junction
# Processing Record 33 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 6 | kupang
# Processing Record 35 of Set 6 | yumen
# Processing Record 36 of Set 6 | mattru
# Processing Record 37 of Set 6 | sao jose da tapera
# Processing Record 38 of Set 6 | acajutla
# Processing Record 39 of Set 6 | amapa
# Processing Record 40 of Set 6 | khani
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | rudsar
# Processing Record 43 of Set 6 | verkhoyansk
# Processing Record 44 of Set 6 | itarema
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | akyab
# Processing Record 47 of Set 6 | tessalit
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | davila
# Processing Record 1 of Set 7 | ketchikan
# Processing Record 2 of Set 7 | kruisfontein
# Processing Record 3 of Set 7 | waingapu
# Processing Record 4 of Set 7 | bundaberg
# Processing Record 5 of Set 7 | tricase
# Processing Record 6 of Set 7 | santiago de cao
# Processing Record 7 of Set 7 | ferkessedougou
# Processing Record 8 of Set 7 | kadoma
# Processing Record 9 of Set 7 | bandarbeyla
# Processing Record 10 of Set 7 | rocha
# Processing Record 11 of Set 7 | pocao de pedras
# Processing Record 12 of Set 7 | demba
# Processing Record 13 of Set 7 | lawton
# Processing Record 14 of Set 7 | mitsamiouli
# Processing Record 15 of Set 7 | fairbanks
# Processing Record 16 of Set 7 | katangli
# Processing Record 17 of Set 7 | mlonggo
# Processing Record 18 of Set 7 | boa vista
# Processing Record 19 of Set 7 | mondlo
# Processing Record 20 of Set 7 | tuy hoa
# Processing Record 21 of Set 7 | guangzhou
# Processing Record 22 of Set 7 | thunder bay
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | alice town
# Processing Record 25 of Set 7 | baglung
# Processing Record 26 of Set 7 | kathmandu
# Processing Record 27 of Set 7 | ngunguru
# Processing Record 28 of Set 7 | ucluelet
# Processing Record 29 of Set 7 | gaya
# Processing Record 30 of Set 7 | betioky
# Processing Record 31 of Set 7 | krasnovishersk
# Processing Record 32 of Set 7 | husavik
# Processing Record 33 of Set 7 | georgetown
# Processing Record 34 of Set 7 | diffa
# Processing Record 35 of Set 7 | klaksvik
# Processing Record 36 of Set 7 | makat
# Processing Record 37 of Set 7 | huarmey
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | bubaque
# Processing Record 40 of Set 7 | tateyama
# Processing Record 41 of Set 7 | morshansk
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | blackwater
# Processing Record 44 of Set 7 | biltine
# Processing Record 45 of Set 7 | iquique
# Processing Record 46 of Set 7 | raga
# Processing Record 47 of Set 7 | kulhudhuffushi
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | turinsk
# Processing Record 50 of Set 7 | melfort
# Processing Record 1 of Set 8 | pacific grove
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | grand gaube
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | chifeng
# Processing Record 6 of Set 8 | nenjiang
# Processing Record 7 of Set 8 | ishigaki
# Processing Record 8 of Set 8 | masallatah
# Processing Record 9 of Set 8 | assiniboia
# Processing Record 10 of Set 8 | teya
# Processing Record 11 of Set 8 | yatou
# Processing Record 12 of Set 8 | acari
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | scarborough
# Processing Record 15 of Set 8 | ternate
# Processing Record 16 of Set 8 | puerto leguizamo
# Processing Record 17 of Set 8 | pochutla
# Processing Record 18 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 8 | manado
# Processing Record 20 of Set 8 | kabelvag
# Processing Record 21 of Set 8 | trelew
# Processing Record 22 of Set 8 | batagay-alyta
# Processing Record 23 of Set 8 | khandagayty
# Processing Record 24 of Set 8 | ponta do sol
# Processing Record 25 of Set 8 | puerto baquerizo moreno
# Processing Record 26 of Set 8 | coro
# Processing Record 27 of Set 8 | olafsvik
# Processing Record 28 of Set 8 | camden
# Processing Record 29 of Set 8 | high level
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | mansion
# City not found. Skipping...
# Processing Record 32 of Set 8 | filotion
# Processing Record 33 of Set 8 | sadiqabad
# Processing Record 34 of Set 8 | strezhevoy
# Processing Record 35 of Set 8 | aginskoye
# Processing Record 36 of Set 8 | jeremie
# Processing Record 37 of Set 8 | powell river
# Processing Record 38 of Set 8 | kaihua
# Processing Record 39 of Set 8 | jurm
# Processing Record 40 of Set 8 | ahipara
# Processing Record 41 of Set 8 | tocopilla
# Processing Record 42 of Set 8 | liverpool
# Processing Record 43 of Set 8 | fort nelson
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | paulesti
# Processing Record 46 of Set 8 | tudor vladimirescu
# Processing Record 47 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 8 | bay roberts
# Processing Record 49 of Set 8 | bonavista
# Processing Record 50 of Set 8 | roblin
# Processing Record 1 of Set 9 | igrim
# Processing Record 2 of Set 9 | burnie
# Processing Record 3 of Set 9 | shirokiy
# Processing Record 4 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 9 | vao
# Processing Record 6 of Set 9 | inhambane
# Processing Record 7 of Set 9 | tomatlan
# Processing Record 8 of Set 9 | high rock
# Processing Record 9 of Set 9 | hanstholm
# Processing Record 10 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 9 | anadyr
# Processing Record 12 of Set 9 | yelovo
# Processing Record 13 of Set 9 | bud
# Processing Record 14 of Set 9 | palmer
# Processing Record 15 of Set 9 | banda aceh
# Processing Record 16 of Set 9 | celestun
# Processing Record 17 of Set 9 | puerto cabezas
# Processing Record 18 of Set 9 | maningrida
# Processing Record 19 of Set 9 | xichang
# Processing Record 20 of Set 9 | cortland
# Processing Record 21 of Set 9 | daru
# Processing Record 22 of Set 9 | nipawin
# Processing Record 23 of Set 9 | juxian
# City not found. Skipping...
# Processing Record 24 of Set 9 | halifax
# Processing Record 25 of Set 9 | shingu
# Processing Record 26 of Set 9 | lorengau
# Processing Record 27 of Set 9 | namibe
# Processing Record 28 of Set 9 | kanashevo
# Processing Record 29 of Set 9 | ixtapa
# Processing Record 30 of Set 9 | panama city
# Processing Record 31 of Set 9 | baza
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | mali
# Processing Record 34 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 9 | adre
# Processing Record 36 of Set 9 | morondava
# Processing Record 37 of Set 9 | sonoita
# Processing Record 38 of Set 9 | santa rosa
# Processing Record 39 of Set 9 | vito
# Processing Record 40 of Set 9 | santa catarina de tepehuanes
# Processing Record 41 of Set 9 | ulladulla
# Processing Record 42 of Set 9 | ambovombe
# Processing Record 43 of Set 9 | yarada
# Processing Record 44 of Set 9 | kaeo
# Processing Record 45 of Set 9 | ereymentau
# Processing Record 46 of Set 9 | launceston
# Processing Record 47 of Set 9 | pervomayskoye
# Processing Record 48 of Set 9 | yulara
# Processing Record 49 of Set 9 | pundaguitan
# Processing Record 50 of Set 9 | moyale
# Processing Record 1 of Set 10 | amga
# Processing Record 2 of Set 10 | sao paulo de olivenca
# Processing Record 3 of Set 10 | ormara
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | montague
# Processing Record 6 of Set 10 | casa nova
# Processing Record 7 of Set 10 | granada
# Processing Record 8 of Set 10 | tornio
# Processing Record 9 of Set 10 | singaparna
# Processing Record 10 of Set 10 | aden
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | barabash
# Processing Record 13 of Set 10 | digha
# Processing Record 14 of Set 10 | lamas
# Processing Record 15 of Set 10 | sorland
# Processing Record 16 of Set 10 | khandyga
# Processing Record 17 of Set 10 | guerrero negro
# Processing Record 18 of Set 10 | siddapur
# Processing Record 19 of Set 10 | flinders
# Processing Record 20 of Set 10 | tselinnoye
# Processing Record 21 of Set 10 | buala
# Processing Record 22 of Set 10 | fryazino
# Processing Record 23 of Set 10 | marsa matruh
# Processing Record 24 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 10 | gat
# Processing Record 26 of Set 10 | beyneu
# Processing Record 27 of Set 10 | escanaba
# Processing Record 28 of Set 10 | yar-sale
# Processing Record 29 of Set 10 | posadas
# Processing Record 30 of Set 10 | dawson creek
# Processing Record 31 of Set 10 | kabalo
# Processing Record 32 of Set 10 | vitim
# Processing Record 33 of Set 10 | chara
# Processing Record 34 of Set 10 | tamale
# Processing Record 35 of Set 10 | mahon
# Processing Record 36 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 10 | berlevag
# Processing Record 38 of Set 10 | korla
# Processing Record 39 of Set 10 | auki
# Processing Record 40 of Set 10 | oga
# Processing Record 41 of Set 10 | abapo
# Processing Record 42 of Set 10 | imeni poliny osipenko
# Processing Record 43 of Set 10 | mahibadhoo
# Processing Record 44 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 10 | liberal
# Processing Record 46 of Set 10 | vrangel
# Processing Record 47 of Set 10 | gondar
# Processing Record 48 of Set 10 | liusha
# Processing Record 49 of Set 10 | port lincoln
# Processing Record 50 of Set 10 | ahuimanu
# Processing Record 1 of Set 11 | yeppoon
# Processing Record 2 of Set 11 | wanxian
# Processing Record 3 of Set 11 | gilbues
# Processing Record 4 of Set 11 | dharchula
# Processing Record 5 of Set 11 | hamilton
# Processing Record 6 of Set 11 | manokwari
# Processing Record 7 of Set 11 | ouesso
# Processing Record 8 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 9 of Set 11 | paamiut
# Processing Record 10 of Set 11 | carbonear
# Processing Record 11 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 11 | turukhansk
# Processing Record 13 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 11 | gandajika
# Processing Record 15 of Set 11 | arecibo
# Processing Record 16 of Set 11 | ust-barguzin
# Processing Record 17 of Set 11 | laguna
# Processing Record 18 of Set 11 | columbus
# Processing Record 19 of Set 11 | sabancuy
# Processing Record 20 of Set 11 | estelle
# Processing Record 21 of Set 11 | ambon
# Processing Record 22 of Set 11 | sistranda
# Processing Record 23 of Set 11 | serebryanyy bor
# Processing Record 24 of Set 11 | cidreira
# Processing Record 25 of Set 11 | sao joao da barra
# Processing Record 26 of Set 11 | luanda
# Processing Record 27 of Set 11 | sterling
# Processing Record 28 of Set 11 | chegdomyn
# Processing Record 29 of Set 11 | faya
# Processing Record 30 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 31 of Set 11 | lagoa
# Processing Record 32 of Set 11 | usinsk
# Processing Record 33 of Set 11 | idenao
# Processing Record 34 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 11 | hervey bay
# Processing Record 36 of Set 11 | forst
# Processing Record 37 of Set 11 | novoagansk
# Processing Record 38 of Set 11 | lubao
# Processing Record 39 of Set 11 | ocean city
# Processing Record 40 of Set 11 | khonsa
# Processing Record 41 of Set 11 | jijiga
# Processing Record 42 of Set 11 | hualmay
# Processing Record 43 of Set 11 | masuguru
# Processing Record 44 of Set 11 | altay
# Processing Record 45 of Set 11 | pandan
# Processing Record 46 of Set 11 | tromso
# Processing Record 47 of Set 11 | martapura
# Processing Record 48 of Set 11 | houma
# Processing Record 49 of Set 11 | mahendranagar
# Processing Record 50 of Set 11 | chima
# Processing Record 1 of Set 12 | athabasca
# Processing Record 2 of Set 12 | pleasantville
# Processing Record 3 of Set 12 | rio claro
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | synya
# Processing Record 6 of Set 12 | abonnema
# Processing Record 7 of Set 12 | boshnyakovo
# Processing Record 8 of Set 12 | le pradet
# Processing Record 9 of Set 12 | cape canaveral
# Processing Record 10 of Set 12 | erkner
# Processing Record 11 of Set 12 | port hedland
# Processing Record 12 of Set 12 | elko
# Processing Record 13 of Set 12 | chicama
# Processing Record 14 of Set 12 | okhotsk
# Processing Record 15 of Set 12 | potosi
# Processing Record 16 of Set 12 | cortes
# Processing Record 17 of Set 12 | saint andrews
# Processing Record 18 of Set 12 | pemba
# Processing Record 19 of Set 12 | touros
# Processing Record 20 of Set 12 | paka
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | christchurch
# Processing Record 24 of Set 12 | riyadh
# Processing Record 25 of Set 12 | moose jaw
# Processing Record 26 of Set 12 | grunstadt
# Processing Record 27 of Set 12 | mecca
# Processing Record 28 of Set 12 | otradnoye
# Processing Record 29 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 12 | rawson
# Processing Record 31 of Set 12 | camacha
# Processing Record 32 of Set 12 | preobrazheniye
# Processing Record 33 of Set 12 | prestea
# Processing Record 34 of Set 12 | maksatikha
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | blythe
# Processing Record 37 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 12 | quatre cocos
# Processing Record 39 of Set 12 | byron bay
# Processing Record 40 of Set 12 | jalu
# Processing Record 41 of Set 12 | bolgatanga
# Processing Record 42 of Set 12 | lalibela
# Processing Record 43 of Set 12 | villanueva de la serena
# Processing Record 44 of Set 12 | kadoshkino
# Processing Record 45 of Set 12 | kargil
# Processing Record 46 of Set 12 | gizo
# Processing Record 47 of Set 12 | maneromango
# Processing Record 48 of Set 12 | hargeysa
# Processing Record 49 of Set 12 | kysyl-syr
# Processing Record 50 of Set 12 | nador
# Processing Record 1 of Set 13 | maldonado
# Processing Record 2 of Set 13 | wawa
# Processing Record 3 of Set 13 | caronport
# Processing Record 4 of Set 13 | shannon
# Processing Record 5 of Set 13 | quelimane
# Processing Record 6 of Set 13 | jacqueville
# Processing Record 7 of Set 13 | tabou
# Processing Record 8 of Set 13 | hallingby
# City not found. Skipping...
# Processing Record 9 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 13 | sungaipenuh
# Processing Record 11 of Set 13 | santa juliana
# Processing Record 12 of Set 13 | valparaiso
# Processing Record 13 of Set 13 | papetoai
# Processing Record 14 of Set 13 | oranjestad
# Processing Record 15 of Set 13 | zadar
# Processing Record 16 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 17 of Set 13 | araguacu
# Processing Record 18 of Set 13 | alice springs
# Processing Record 19 of Set 13 | mogadishu
# Processing Record 20 of Set 13 | altamira
# Processing Record 21 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 22 of Set 13 | goderich
# Processing Record 23 of Set 13 | kabo
# Processing Record 24 of Set 13 | ca mau
# Processing Record 25 of Set 13 | pecos
# Processing Record 26 of Set 13 | bardiyah
# Processing Record 27 of Set 13 | do gonbadan
# Processing Record 28 of Set 13 | kavaratti
# Processing Record 29 of Set 13 | albania
# Processing Record 30 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 13 | qui nhon
# Processing Record 33 of Set 13 | hailar
# Processing Record 34 of Set 13 | santa marta
# Processing Record 35 of Set 13 | ewa beach
# Processing Record 36 of Set 13 | miraflores
# Processing Record 37 of Set 13 | antalaha
# Processing Record 38 of Set 13 | puerto ayacucho
# Processing Record 39 of Set 13 | kuala lipis
# Processing Record 40 of Set 13 | senneterre
# Processing Record 41 of Set 13 | pontes e lacerda
# Processing Record 42 of Set 13 | iwanai
# Processing Record 43 of Set 13 | korop
# Processing Record 44 of Set 13 | mossendjo
# Processing Record 45 of Set 13 | sur
# Processing Record 46 of Set 13 | carutapera
# Processing Record 47 of Set 13 | beisfjord
# Processing Record 48 of Set 13 | pithiviers
# Processing Record 49 of Set 13 | finschhafen
# Processing Record 50 of Set 13 | tongchuan
# Processing Record 1 of Set 14 | shitanjing
# Processing Record 2 of Set 14 | santa lucia
# Processing Record 3 of Set 14 | muzhi
# Processing Record 4 of Set 14 | mzimba
# Processing Record 5 of Set 14 | minab
# Processing Record 6 of Set 14 | elk city
# Processing Record 7 of Set 14 | griffith
# Processing Record 8 of Set 14 | san jose
# Processing Record 9 of Set 14 | penzance
# Processing Record 10 of Set 14 | araouane
# Processing Record 11 of Set 14 | iisalmi
# Processing Record 12 of Set 14 | kultuk
# Processing Record 13 of Set 14 | zhigansk
# Processing Record 14 of Set 14 | valerianovsk
# Processing Record 15 of Set 14 | pangody
# Processing Record 16 of Set 14 | san ramon de la nueva oran
# Processing Record 17 of Set 14 | maltahohe
# Processing Record 18 of Set 14 | carahue
# Processing Record 19 of Set 14 | basoko
# Processing Record 20 of Set 14 | krasnyy yar
# Processing Record 21 of Set 14 | san quintin
# Processing Record 22 of Set 14 | poya
# Processing Record 23 of Set 14 | springfield
# Processing Record 24 of Set 14 | sao miguel do araguaia
# Processing Record 25 of Set 14 | moose factory
# Processing Record 26 of Set 14 | mackay
# Processing Record 27 of Set 14 | siuna
# Processing Record 28 of Set 14 | skibbereen
# Processing Record 29 of Set 14 | enshi
# Processing Record 30 of Set 14 | los alamos
# Processing Record 31 of Set 14 | mporokoso
# Processing Record 32 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 14 | zhanaozen
# Processing Record 34 of Set 14 | senno
# Processing Record 35 of Set 14 | walvis bay
# Processing Record 36 of Set 14 | weatherford
# Processing Record 37 of Set 14 | baleshwar
# Processing Record 38 of Set 14 | port macquarie
# Processing Record 39 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 14 | shache
# Processing Record 41 of Set 14 | portland
# Processing Record 42 of Set 14 | chateauroux
# Processing Record 43 of Set 14 | crixas
# Processing Record 44 of Set 14 | ayutla
# Processing Record 45 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 14 | sines
# Processing Record 47 of Set 14 | hanna
# Processing Record 48 of Set 14 | fuerte olimpo
# Processing Record 49 of Set 14 | port pirie
# Processing Record 50 of Set 14 | asau
# Processing Record 1 of Set 15 | marabba
# Processing Record 2 of Set 15 | saint-joseph
# Processing Record 3 of Set 15 | kidal
# Processing Record 4 of Set 15 | monrovia
# Processing Record 5 of Set 15 | tubuala
# Processing Record 6 of Set 15 | diamantino
# Processing Record 7 of Set 15 | himora
# City not found. Skipping...
# Processing Record 8 of Set 15 | wolfsberg
# Processing Record 9 of Set 15 | craig
# Processing Record 10 of Set 15 | whitehorse
# Processing Record 11 of Set 15 | kuvandyk
# Processing Record 12 of Set 15 | lodja
# Processing Record 13 of Set 15 | kloulklubed
# Processing Record 14 of Set 15 | frutal
# Processing Record 15 of Set 15 | morgan city
# Processing Record 16 of Set 15 | luganville
# Processing Record 17 of Set 15 | ochakiv
# Processing Record 18 of Set 15 | seeboden
# Processing Record 19 of Set 15 | bodajk
# Processing Record 20 of Set 15 | itapora
# Processing Record 21 of Set 15 | vestmannaeyjar
# Processing Record 22 of Set 15 | smila
# Processing Record 23 of Set 15 | bagdarin
# Processing Record 24 of Set 15 | ziniare
# Processing Record 25 of Set 15 | placido de castro
# Processing Record 26 of Set 15 | maple creek
# Processing Record 27 of Set 15 | neuquen
# Processing Record 28 of Set 15 | savinka
# Processing Record 29 of Set 15 | kurchum
# Processing Record 30 of Set 15 | yerofey pavlovich
# Processing Record 31 of Set 15 | herat
# Processing Record 32 of Set 15 | samana
# Processing Record 33 of Set 15 | gambela
# Processing Record 34 of Set 15 | broken hill
# Processing Record 35 of Set 15 | henties bay
# Processing Record 36 of Set 15 | nalut
# Processing Record 37 of Set 15 | dwarka
# Processing Record 38 of Set 15 | manaure
# Processing Record 39 of Set 15 | novyy urengoy
# Processing Record 40 of Set 15 | keelung
# Processing Record 41 of Set 15 | taicheng
# Processing Record 42 of Set 15 | bonga
# Processing Record 43 of Set 15 | rundu
# Processing Record 44 of Set 15 | vyzhnytsya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp      Current Description  \
# 0         Victoria  22.2855  114.1577     82.45          overcast clouds
# 1     Punta Arenas -53.1500  -70.9167     35.71            broken clouds
# 2           Dikson  73.5069   80.5464     28.67            broken clouds
# 3  Arraial Do Cabo -22.9661  -42.0278     68.47               few clouds
# 4    Ponta Delgada  37.7333  -25.6667     68.50  light intensity drizzle
# 5      East London -33.0153   27.9116     52.74               few clouds
# 6        Malangali  -8.5667   34.8500     62.33          overcast clouds
# 7          Ushuaia -54.8000  -68.3000     37.06                clear sky
# 8    Mount Gambier -37.8333  140.7667     62.33                clear sky
# 9   Saint-Philippe -21.3585   55.7679     76.59               few clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        81          97       17.00      HK
# 1        87          75        5.75      CL
# 2        88          67       12.62      RU
# 3        74          11        6.06      BR
# 4        94          75        3.44      PT
# 5        87          20        5.75      ZA
# 6        80          99        8.14      TZ
# 7        81           0        6.91      AR
# 8        52           2        5.10      AU
# 9        74          18        9.69      RE

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Victoria      HK  22.2855  114.1577     82.45        81          97
# 1     Punta Arenas      CL -53.1500  -70.9167     35.71        87          75
# 2           Dikson      RU  73.5069   80.5464     28.67        88          67
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     68.47        74          11
# 4    Ponta Delgada      PT  37.7333  -25.6667     68.50        94          75
# 5      East London      ZA -33.0153   27.9116     52.74        87          20
# 6        Malangali      TZ  -8.5667   34.8500     62.33        80          99
# 7          Ushuaia      AR -54.8000  -68.3000     37.06        81           0
# 8    Mount Gambier      AU -37.8333  140.7667     62.33        52           2
# 9   Saint-Philippe      RE -21.3585   55.7679     76.59        74          18
#
#    Wind Speed      Current Description
# 0       17.00          overcast clouds
# 1        5.75            broken clouds
# 2       12.62            broken clouds
# 3        6.06               few clouds
# 4        3.44  light intensity drizzle
# 5        5.75               few clouds
# 6        8.14          overcast clouds
# 7        6.91                clear sky
# 8        5.10                clear sky
# 9        9.69               few clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
